# %%
import pandas as pd
import numpy as np
import statistics as st
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/WineQT.csv")
data.head()
# Out:
#    Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   0            7.4              0.70         0.00             1.9
# 1   1            7.8              0.88         0.00             2.6
# 2   2            7.8              0.76         0.04             2.3
# 3   3           11.2              0.28         0.56             1.9
# 4   4            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5
# ...

# %%
data.columns
# Out:
# Index(['Id', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    1143 non-null   int64
#  1   fixed acidity         1143 non-null   float64
#  2   volatile acidity      1143 non-null   float64
#  3   citric acid           1143 non-null   float64
#  4   residual sugar        1143 non-null   float64
#  5   chlorides             1143 non-null   float64
#  6   free sulfur dioxide   1143 non-null   float64
#  7   total sulfur dioxide  1143 non-null   float64
#  8   density               1143 non-null   float64
#  9   pH                    1143 non-null   float64
#  10  sulphates             1143 non-null   float64
#  11  alcohol               1143 non-null   float64
#  12  quality               1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
data.tail()
# Out:
#         Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1138  1592            6.3             0.510         0.13             2.3
# 1139  1593            6.8             0.620         0.08             1.9
# 1140  1594            6.2             0.600         0.08             2.0
# 1141  1595            5.9             0.550         0.10             2.2
# 1142  1597            5.9             0.645         0.12             2.0
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1138      0.076                 29.0                  40.0  0.99574  3.42
# 1139      0.068                 28.0                  38.0  0.99651  3.42
# 1140      0.090                 32.0                  44.0  0.99490  3.45
# 1141      0.062                 39.0                  51.0  0.99512  3.52
# 1142      0.075                 32.0                  44.0  0.99547  3.57
#
#       sulphates  alcohol  quality
# 1138       0.75     11.0        6
# ...

# %%
data.count()
# Out:
# Id                      1143
# fixed acidity           1143
# volatile acidity        1143
# citric acid             1143
# residual sugar          1143
# chlorides               1143
# free sulfur dioxide     1143
# total sulfur dioxide    1143
# density                 1143
# pH                      1143
# sulphates               1143
# alcohol                 1143
# quality                 1143
# dtype: int64

# %%
data.describe()
# Out:
#                 Id  fixed acidity  volatile acidity  citric acid  \
# count  1143.000000    1143.000000       1143.000000  1143.000000
# mean    804.969379       8.311111          0.531339     0.268364
# std     463.997116       1.747595          0.179633     0.196686
# min       0.000000       4.600000          0.120000     0.000000
# 25%     411.000000       7.100000          0.392500     0.090000
# 50%     794.000000       7.900000          0.520000     0.250000
# 75%    1209.500000       9.100000          0.640000     0.420000
# max    1597.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1143.000000  1143.000000          1143.000000           1143.000000
# mean         2.532152     0.086933            15.615486             45.914698
# std          1.355917     0.047267            10.250486             32.782130
# ...

# %%
data.drop(["citric acid", "residual sugar", "chlorides"], axis=1, inplace=True)

print(data)
# Out:
#         Id  fixed acidity  volatile acidity  free sulfur dioxide  \
# 0        0            7.4             0.700                 11.0
# 1        1            7.8             0.880                 25.0
# 2        2            7.8             0.760                 15.0
# 3        3           11.2             0.280                 17.0
# 4        4            7.4             0.700                 11.0
# ...    ...            ...               ...                  ...
# 1138  1592            6.3             0.510                 29.0
# 1139  1593            6.8             0.620                 28.0
# 1140  1594            6.2             0.600                 32.0
# 1141  1595            5.9             0.550                 39.0
# 1142  1597            5.9             0.645                 32.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                     34.0  0.99780  3.51       0.56      9.4        5
# ...

# %%
mx = data['quality'].max()
mn = data['quality'].min()
print(f"max:{mx}\tmin:{mn}\nrange:{mx-mn}")
# Out:
# max:8	min:3
# range:5

# %%
correlation = data.corr()
correlation
# Out:
#                             Id  fixed acidity  volatile acidity  \
# Id                    1.000000      -0.275826         -0.007892
# fixed acidity        -0.275826       1.000000         -0.250728
# volatile acidity     -0.007892      -0.250728          1.000000
# free sulfur dioxide   0.095268      -0.164831         -0.001962
# total sulfur dioxide -0.107389      -0.110628          0.077748
# density              -0.363926       0.681501          0.016512
# pH                    0.132904      -0.685163          0.221492
# sulphates            -0.103954       0.174592         -0.276079
# alcohol               0.238087      -0.075055         -0.203909
# quality               0.069708       0.121970         -0.407394
#
#                       free sulfur dioxide  total sulfur dioxide   density  \
# Id                               0.095268             -0.107389 -0.363926
# fixed acidity                   -0.164831             -0.110628  0.681501
# ...

# %%
print(df.isnull().sum())
# Out:
# Id                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.nunique()
# Out:
# Id                      1143
# fixed acidity             91
# volatile acidity         135
# free sulfur dioxide       53
# total sulfur dioxide     138
# density                  388
# pH                        87
# sulphates                 89
# alcohol                   61
# quality                    6
# dtype: int64

# %%
mx = data['quality'].max()
mn = data['quality'].min()
print(f"max:{mx}\tmin:{mn}\nrange:{mx-mn}")
# Out:
# max:8	min:3
# range:5

# %%
df = data
df['quality'].sum()
# Out:
# 6466

# %%
df['quality'].max()
# Out:
# 8

# %%
df['quality'].min()
# Out:
# 3

# %%
df['quality'].mode()
# Out:
# 0    5
# Name: quality, dtype: int64

# %%
df['quality'].median()
# Out:
# 6.0

# %%
df['quality'].std()
# Out:
# 0.8058242481000952

# %%
np.percentile(df['quality'],50)
# Out:
# 6.0

# %%
print(df.isnull().sum())
# Out:
# Id                      0
# fixed acidity           0
# volatile acidity        0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data = df.drop(['Id'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   free sulfur dioxide   1143 non-null   float64
#  3   total sulfur dioxide  1143 non-null   float64
#  4   density               1143 non-null   float64
#  5   pH                    1143 non-null   float64
#  6   sulphates             1143 non-null   float64
#  7   alcohol               1143 non-null   float64
#  8   quality               1143 non-null   int64
# dtypes: float64(8), int64(1)
# memory usage: 80.5 KB

# %%
correlation["quality"] * 100
# Out:
# Id                        6.970824
# fixed acidity            12.197010
# volatile acidity        -40.739351
# free sulfur dioxide      -6.325964
# total sulfur dioxide    -18.333915
# density                 -17.520792
# pH                       -5.245303
# sulphates                25.771026
# alcohol                  48.486621
# quality                 100.000000
# Name: quality, dtype: float64

# %%
import seaborn as sns
sns.catplot(x='quality', data=data, kind='count')

# %%
df.hist(figsize=(14, 12), bins=10, color='red', edgecolor='black')
plt.suptitle('Histograms of Numerical Features')
plt.show()

# %%
corr_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 10))
for i, column in enumerate(data.columns[:-1]):
 plt.subplot(3, 4, i+1)
 sns.boxplot(y=data[column], color='lightcoral')
 plt.title(f'Boxplot of {column}')
plt.tight_layout()
plt.show()
